# %% [markdown]
# 1. Read the dataset to the python environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset

# %%
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]
# No charts were generated by quickchart

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# meaningful visualizations.

# %%
data = {
   'SL': np.random.normal(loc=5.5, scale=0.8, size=150),
    'SW': np.random.normal(loc=3.0, scale=0.4, size=150),
    'PL': np.random.normal(loc=4.5, scale=1.0, size=150),
    'PW': np.random.normal(loc=1.3, scale=0.5, size=150),
   'Classification': np.random.choice(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], size=150)
}

df = pd.DataFrame(data)


sns.pairplot(df, hue='Classification', markers=["o", "s", "D"])
plt.suptitle('Pairplot of Iris Features by Classification', y=1.02)
plt.show()


plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['SL', 'SW', 'PL', 'PW']], hue=df['Classification'])
plt.title('Boxplot of Iris Sepal and Petal Measurements')
plt.show()


plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PL', y='PW', hue='Classification', style='Classification', markers=["o", "s", "D"])
plt.title('Petal Length vs Petal Width by Classification')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-609c22bc9776> in <cell line: 18>()
#      16
#      17 plt.figure(figsize=(12, 6))
# ---> 18 sns.boxplot(data=df[['SL', 'SW', 'PL', 'PW']], hue=df['Classification'])
#      19 plt.title('Boxplot of Iris Sepal and Petal Measurements')
#      20 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1595 ):
#    1596
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#
# ...
